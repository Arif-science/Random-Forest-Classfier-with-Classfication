# %%
import numpy as np

import pandas as pd
#import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_text

# %%
df = pd.read_csv(r"marketing.csv")
df
# Out:
#           ID  age         job  marital  education default  balance housing  \
# 0      13829   29  technician   single   tertiary      no    18254      no
# 1      22677   26    services   single  secondary      no      512     yes
# 2      10541   30  management   single  secondary      no      135      no
# 3      13689   41  technician  married    unknown      no       30     yes
# 4      11304   27      admin.   single  secondary      no      321      no
# ...      ...  ...         ...      ...        ...     ...      ...     ...
# 12865  14023   47  technician  married  secondary      no     1167     yes
# 12866  17259   31     unknown  married  secondary      no      111      no
# 12867  15200   37  unemployed   single   tertiary      no     1316     yes
# 12868  13775   42  management  married   tertiary      no      479     yes
# 12869  20137   24    services   single  secondary      no        0      no
#
# ...

# %%
df.describe(include='all')
# Out:
#                   ID           age         job  marital  education default  \
# count   12870.000000  12870.000000       12870    12870      12870   12870
# unique           NaN           NaN          12        3          4       2
# top              NaN           NaN  management  married  secondary      no
# freq             NaN           NaN        2858     7490       6368   12662
# mean    16434.500000     41.091142         NaN      NaN        NaN     NaN
# std      3715.393317     11.305560         NaN      NaN        NaN     NaN
# min     10000.000000     18.000000         NaN      NaN        NaN     NaN
# 25%     13217.250000     32.000000         NaN      NaN        NaN     NaN
# 50%     16434.500000     39.000000         NaN      NaN        NaN     NaN
# 75%     19651.750000     49.000000         NaN      NaN        NaN     NaN
# max     22869.000000     95.000000         NaN      NaN        NaN     NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# campaign     0
# pdays        0
# previous     0
# response     0
# result       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'campaign', 'pdays',
#        'previous', 'response', 'result'],
#       dtype='object')

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# ID 12870
# age 76
# job 12
# marital 3
# education 4
# default 2
# balance 4188
# housing 2
# loan 2
# contact 3
# day 31
# month 12
# campaign 36
# pdays 461
# previous 30
# response 4
# result 2

# %%
df = df.drop(columns=["ID", "pdays", "previous"])
df
# Out:
#        age         job  marital  education default  balance housing loan  \
# 0       29  technician   single   tertiary      no    18254      no   no
# 1       26    services   single  secondary      no      512     yes  yes
# 2       30  management   single  secondary      no      135      no   no
# 3       41  technician  married    unknown      no       30     yes   no
# 4       27      admin.   single  secondary      no      321      no  yes
# ...    ...         ...      ...        ...     ...      ...     ...  ...
# 12865   47  technician  married  secondary      no     1167     yes   no
# 12866   31     unknown  married  secondary      no      111      no   no
# 12867   37  unemployed   single   tertiary      no     1316     yes   no
# 12868   42  management  married   tertiary      no      479     yes   no
# 12869   24    services   single  secondary      no        0      no   no
#
#         contact  day month  campaign response result
# ...

# %%
df["result"] = df["result"].map({"yes": 0, "no": 1})
df
# Out:
#        age         job  marital  education default  balance housing loan  \
# 0       29  technician   single   tertiary      no    18254      no   no
# 1       26    services   single  secondary      no      512     yes  yes
# 2       30  management   single  secondary      no      135      no   no
# 3       41  technician  married    unknown      no       30     yes   no
# 4       27      admin.   single  secondary      no      321      no  yes
# ...    ...         ...      ...        ...     ...      ...     ...  ...
# 12865   47  technician  married  secondary      no     1167     yes   no
# 12866   31     unknown  married  secondary      no      111      no   no
# 12867   37  unemployed   single   tertiary      no     1316     yes   no
# 12868   42  management  married   tertiary      no      479     yes   no
# 12869   24    services   single  secondary      no        0      no   no
#
#         contact  day month  campaign response  result
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isnull().mean()*100
# Out:
# age          0.0
# job          0.0
# marital      0.0
# education    0.0
# default      0.0
# balance      0.0
# housing      0.0
# loan         0.0
# contact      0.0
# day          0.0
# month        0.0
# campaign     0.0
# response     0.0
# result       0.0
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le =LabelEncoder()

# %%
categorical_cols= ['job','marital','default','balance','loan','campaign','month', 'response', 'contact']

# %%
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])
df
# Out:
#        age  job  marital  education  default  balance housing  loan  contact  \
# 0       29    9        2   tertiary        0     4114      no     0        0
# 1       26    7        2  secondary        0     1033     yes     1        2
# 2       30    4        2  secondary        0      656      no     0        0
# 3       41    9        1    unknown        0      551     yes     0        0
# 4       27    0        2  secondary        0      842      no     1        2
# ...    ...  ...      ...        ...      ...      ...     ...   ...      ...
# 12865   47    9        1  secondary        0     1652     yes     0        0
# 12866   31   11        1  secondary        0      632      no     0        0
# 12867   37   10        2   tertiary        0     1785     yes     0        0
# 12868   42    4        1   tertiary        0     1000     yes     0        2
# 12869   24    7        2  secondary        0      521      no     0        2
#
# ...

# %%
df.education.value_counts()
# Out:
# education
# secondary    6368
# tertiary     4075
# primary      1880
# unknown       547
# Name: count, dtype: int64

# %%
education_mapping ={"secondary":1,
                   "tertiary":2,
                   "primary":3,
                   "unknown":4}
df["education"] = df["education"].map(education_mapping)

df
# Out:
#        age  job  marital  education  default  balance housing  loan  contact  \
# 0       29    9        2          2        0     4114      no     0        0
# 1       26    7        2          1        0     1033     yes     1        2
# 2       30    4        2          1        0      656      no     0        0
# 3       41    9        1          4        0      551     yes     0        0
# 4       27    0        2          1        0      842      no     1        2
# ...    ...  ...      ...        ...      ...      ...     ...   ...      ...
# 12865   47    9        1          1        0     1652     yes     0        0
# 12866   31   11        1          1        0      632      no     0        0
# 12867   37   10        2          2        0     1785     yes     0        0
# 12868   42    4        1          2        0     1000     yes     0        2
# 12869   24    7        2          1        0      521      no     0        2
#
# ...

# %%
df.housing.value_counts()
# Out:
# housing
# yes    6605
# no     6265
# Name: count, dtype: int64

# %%
housing_mapping={"yes":2,
                 "no":1}
df["housing"] = df["housing"].map(housing_mapping)

df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       29    9        2          2        0     4114        1     0        0
# 1       26    7        2          1        0     1033        2     1        2
# 2       30    4        2          1        0      656        1     0        0
# 3       41    9        1          4        0      551        2     0        0
# 4       27    0        2          1        0      842        1     1        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 12865   47    9        1          1        0     1652        2     0        0
# 12866   31   11        1          1        0      632        1     0        0
# 12867   37   10        2          2        0     1785        2     0        0
# 12868   42    4        1          2        0     1000        2     0        2
# 12869   24    7        2          1        0      521        1     0        2
#
# ...

# %%
# Asılı dəyişən (target / output)
y = df['result']

# Müstəqil dəyişənlər (inputs / features) - result sütunu çıxılır
X = df.drop('result', axis=1)

print("X sütunları (müstəqil dəyişənlər):")
print(X.columns.tolist())

print("\ny dəyişəni (asılı dəyişən):")
print(y.name)
# Out:
# X sütunları (müstəqil dəyişənlər):
# ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'campaign', 'response']
#
# y dəyişəni (asılı dəyişən):
# result

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def evaluate(model, X_train, y_train, X_test, y_test):
    
    '''Predictions and probabilities for the training set'''
    
    y_train_pred = model.predict(X_train)
    y_train_prob = model.predict_proba(X_train)[:, 1]

    '''Predictions and probabilities for the test set'''
    
    y_test_pred = model.predict(X_test)
    y_test_prob = model.predict_proba(X_test)[:, 1]

    '''Calculate metrics for the training set''' 
    
    roc_train_prob = roc_auc_score(y_train, y_train_prob)
    gini_train_prob = roc_train_prob * 2 - 1
    precision_train = precision_score(y_train, y_train_pred)
    recall_train = recall_score(y_train, y_train_pred)

    '''Calculate metrics for the test set'''
    
    roc_test_prob = roc_auc_score(y_test, y_test_prob)
    gini_test_prob = roc_test_prob * 2 - 1
    precision_test = precision_score(y_test, y_test_pred)
    recall_test = recall_score(y_test, y_test_pred)

    results = pd.DataFrame({
        'Dataset': ['Train', 'Test'],
        'Gini': [gini_train_prob * 100, gini_test_prob * 100],
        'Precision': [precision_train, precision_test],
        'Recall': [recall_train, recall_test]
    })

    return results

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=100,random_state=42)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
one_tree = rfc.estimators_[9]

tree_rules_rf = export_text(one_tree, feature_names=list(X_train.columns))
print(tree_rules_rf)
# Out:
# |--- job <= 3.50
# |   |--- response <= 2.50
# |   |   |--- response <= 1.50
# |   |   |   |--- month <= 10.50
# |   |   |   |   |--- balance <= 3959.00
# |   |   |   |   |   |--- balance <= 1900.00
# |   |   |   |   |   |   |--- campaign <= 1.50
# |   |   |   |   |   |   |   |--- day <= 29.50
# |   |   |   |   |   |   |   |   |--- housing <= 1.50
# |   |   |   |   |   |   |   |   |   |--- month <= 7.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 54.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- age >  54.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- month >  7.00
# |   |   |   |   |   |   |   |   |   |   |--- response <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- response >  0.50
# ...

# %%
result = evaluate(rfc, X_train, y_train, X_test, y_test)
result
# Out:
#   Dataset        Gini  Precision    Recall
# 0   Train  100.000000    1.00000  1.000000
# 1    Test   52.548683    0.79974  0.913608

# %%
def plot_feature_importances(model, feature_names):
    
    importances = model.feature_importances_
    
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    }).sort_values(by="Importance", ascending=False)
   
    
   # plt.figure(figsize=(10, 6))
   # plt.barh(importance_df['Feature'], importance_df['Importance'])
   # plt.title("Feature Importances")
   # plt.xlabel("Importance Score")
   # plt.ylabel("Feature")
   # plt.gca().invert_yaxis() 
   # plt.show()
    
    return importance_df

# %%
feature_names = X_train.columns

feature_importance_df = plot_feature_importances(rfc, feature_names)

feature_importance_df
# Out:
#       Feature  Importance
# 5     balance    0.187153
# 0         age    0.166868
# 9         day    0.140387
# 10      month    0.115064
# 1         job    0.077007
# 12   response    0.071237
# 11   campaign    0.068973
# 8     contact    0.044920
# 3   education    0.041042
# 2     marital    0.034766
# 6     housing    0.033061
# 7        loan    0.016560
# 4     default    0.002961

# %%
X_train.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'campaign', 'response'],
#       dtype='object')

# %%
clfRF_selected = RandomForestClassifier(random_state=42)

clfRF_selected.fit(X_train[['balance','age','day','job','response','campaign']],y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
result = evaluate(clfRF_selected, X_train[['balance','age','day','job','response','campaign']],y_train,
                  X_test[['balance','age','day','job','response','campaign']], y_test)
result
# Out:
#   Dataset       Gini  Precision   Recall
# 0   Train  99.999983   0.999839  1.00000
# 1    Test  36.988247   0.768937  0.89581

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 10)]
max_depth = [int(x) for x in np.linspace(10, 100, num = 11)]


random_grid = {'n_estimators': n_estimators, 
               'max_features': ['sqrt', 0.3, 0.5, None], 
               'max_depth': max_depth, 
               'min_samples_split': [20,50],
               'min_samples_leaf': [5, 8, 10]} 
print(random_grid)
# Out:
# {'n_estimators': [200, 288, 377, 466, 555, 644, 733, 822, 911, 1000], 'max_features': ['sqrt', 0.3, 0.5, None], 'max_depth': [10, 19, 28, 37, 46, 55, 64, 73, 82, 91, 100], 'min_samples_split': [20, 50], 'min_samples_leaf': [5, 8, 10]}

# %%
rf_random = RandomizedSearchCV(
                    estimator=rfc, 
                    param_distributions=random_grid, 
                    n_iter=50,  
                    cv=3, 
                    verbose=1, 
                    random_state=42, 
                    n_jobs=-1)


rf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'max_depth': [10, 19, 28, 37, 46, 55,
#                                                       64, 73, 82, 91, 100],
#                                         'max_features': ['sqrt', 0.3, 0.5,
#                                                          None],
#                                         'min_samples_leaf': [5, 8, 10],
#                                         'min_samples_split': [20, 50],
#                                         'n_estimators': [200, 288, 377, 466,
#                                                          555, 644, 733, 822,
#                                                          911, 1000]},
#                    random_state=42, verbose=1)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 466,
#  'min_samples_split': 50,
#  'min_samples_leaf': 8,
#  'max_features': 0.5,
#  'max_depth': 46}

# %%
optimized_model = rf_random.best_estimator_
evaluate(optimized_model, X_train, y_train, X_test, y_test)
# Out:
#   Dataset       Gini  Precision    Recall
# 0   Train  75.704292   0.807355  0.933935
# 1    Test  54.621847   0.797074  0.929181

# %%
one_tree = optimized_model.estimators_[9]

tree_rules_rf_opt = export_text(one_tree, feature_names=list(X_train.columns))
print(tree_rules_rf_opt)
# Out:
# |--- response <= 2.50
# |   |--- job <= 2.50
# |   |   |--- housing <= 1.50
# |   |   |   |--- response <= 0.50
# |   |   |   |   |--- balance <= 674.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- balance >  674.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- response >  0.50
# |   |   |   |   |--- day <= 5.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- day >  5.50
# |   |   |   |   |   |--- balance <= 2733.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- balance >  2733.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- housing >  1.50
# |   |   |   |--- month <= 9.50
# |   |   |   |   |--- response <= 1.50
# |   |   |   |   |   |--- day <= 24.00
# |   |   |   |   |   |   |--- month <= 0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- month >  0.50
# |   |   |   |   |   |   |   |--- month <= 7.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# ...

# %%
optimized_model.classes_
# Out:
# array([0, 1])

# %%
data = pd.read_excel(r'marketing_test.xlsx')
data
# Out:
#       ID  age          job   marital  education default  balance housing loan  \
# 0    812   25  blue-collar    single  secondary      no      764     yes   no
# 1     71   40  blue-collar    single    primary      no      118      no   no
# 2    912   27       admin.  divorced  secondary      no      451     yes   no
# 3     43   30     services    single  secondary      no      495     yes   no
# 4    431   36  blue-collar   married    primary      no     1548     yes  yes
# ..   ...  ...          ...       ...        ...     ...      ...     ...  ...
# 852   49   43  blue-collar   married  secondary      no      413     yes   no
# 853  409   56   management   married   tertiary      no     1282      no   no
# 854  105   54       admin.   married    primary      no      976     yes   no
# 855  810   30   unemployed    single   tertiary      no     1159      no   no
# 856  410   52  blue-collar   married  secondary      no     1860      no   no
#
# ...

# %%
data.describe(include ="all")
# Out:
#                 ID         age         job  marital  education default  \
# count   857.000000  857.000000         857      857        857     857
# unique         NaN         NaN          12        3          4       2
# top            NaN         NaN  management  married  secondary      no
# freq           NaN         NaN         184      480        422     837
# mean    500.905484   40.213536         NaN      NaN        NaN     NaN
# std     291.755233   10.970964         NaN      NaN        NaN     NaN
# min       1.000000   18.000000         NaN      NaN        NaN     NaN
# 25%     247.000000   32.000000         NaN      NaN        NaN     NaN
# 50%     496.000000   38.000000         NaN      NaN        NaN     NaN
# 75%     758.000000   47.000000         NaN      NaN        NaN     NaN
# max     999.000000   83.000000         NaN      NaN        NaN     NaN
#
#              balance housing loan   contact         day month    campaign  \
# ...

# %%
data.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# campaign     0
# pdays        0
# previous     0
# response     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'campaign', 'pdays',
#        'previous', 'response'],
#       dtype='object')

# %%
data = data.drop(columns=["pdays", "previous"],axis=1)
data
# Out:
#       ID  age          job   marital  education default  balance housing loan  \
# 0    812   25  blue-collar    single  secondary      no      764     yes   no
# 1     71   40  blue-collar    single    primary      no      118      no   no
# 2    912   27       admin.  divorced  secondary      no      451     yes   no
# 3     43   30     services    single  secondary      no      495     yes   no
# 4    431   36  blue-collar   married    primary      no     1548     yes  yes
# ..   ...  ...          ...       ...        ...     ...      ...     ...  ...
# 852   49   43  blue-collar   married  secondary      no      413     yes   no
# 853  409   56   management   married   tertiary      no     1282      no   no
# 854  105   54       admin.   married    primary      no      976     yes   no
# 855  810   30   unemployed    single   tertiary      no     1159      no   no
# 856  410   52  blue-collar   married  secondary      no     1860      no   no
#
# ...

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.isnull().mean()*100
# Out:
# ID           0.0
# age          0.0
# job          0.0
# marital      0.0
# education    0.0
# default      0.0
# balance      0.0
# housing      0.0
# loan         0.0
# contact      0.0
# day          0.0
# month        0.0
# campaign     0.0
# response     0.0
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le =LabelEncoder()

# %%
categorical_cols= ['job','marital','default','balance','loan','campaign','month', 'response', 'contact']

# %%
for col in categorical_cols:
    data[col] = le.fit_transform(data[col])
data
# Out:
#       ID  age  job  marital  education  default  balance housing  loan  \
# 0    812   25    1        2  secondary        0      325     yes     0
# 1     71   40    1        2    primary        0      111      no     0
# 2    912   27    0        0  secondary        0      246     yes     0
# 3     43   30    7        2  secondary        0      262     yes     0
# 4    431   36    1        1    primary        0      452     yes     1
# ..   ...  ...  ...      ...        ...      ...      ...     ...   ...
# 852   49   43    1        1  secondary        0      236     yes     0
# 853  409   56    4        1   tertiary        0      420      no     0
# 854  105   54    0        1    primary        0      378     yes     0
# 855  810   30   10        2   tertiary        0      398      no     0
# 856  410   52    1        1  secondary        0      479      no     0
#
#      contact  day  month  campaign  response
# 0          0   18      8         0         3
# ...

# %%
data.education.value_counts()
# Out:
# education
# secondary    422
# tertiary     276
# primary      129
# unknown       30
# Name: count, dtype: int64

# %%
education_mapping ={"secondary":1,
                   "tertiary":2,
                   "primary":3,
                   "unknown":4}
data["education"] = data["education"].map(education_mapping)

data
# Out:
#       ID  age  job  marital  education  default  balance housing  loan  \
# 0    812   25    1        2          1        0      325     yes     0
# 1     71   40    1        2          3        0      111      no     0
# 2    912   27    0        0          1        0      246     yes     0
# 3     43   30    7        2          1        0      262     yes     0
# 4    431   36    1        1          3        0      452     yes     1
# ..   ...  ...  ...      ...        ...      ...      ...     ...   ...
# 852   49   43    1        1          1        0      236     yes     0
# 853  409   56    4        1          2        0      420      no     0
# 854  105   54    0        1          3        0      378     yes     0
# 855  810   30   10        2          2        0      398      no     0
# 856  410   52    1        1          1        0      479      no     0
#
#      contact  day  month  campaign  response
# 0          0   18      8         0         3
# ...

# %%
data.housing.value_counts()
# Out:
# housing
# yes    461
# no     396
# Name: count, dtype: int64

# %%
housing_mapping={"yes":2,
                 "no":1}
data["housing"] = data["housing"].map(housing_mapping)

data
# Out:
#       ID  age  job  marital  education  default  balance  housing  loan  \
# 0    812   25    1        2          1        0      325        2     0
# 1     71   40    1        2          3        0      111        1     0
# 2    912   27    0        0          1        0      246        2     0
# 3     43   30    7        2          1        0      262        2     0
# 4    431   36    1        1          3        0      452        2     1
# ..   ...  ...  ...      ...        ...      ...      ...      ...   ...
# 852   49   43    1        1          1        0      236        2     0
# 853  409   56    4        1          2        0      420        1     0
# 854  105   54    0        1          3        0      378        2     0
# 855  810   30   10        2          2        0      398        1     0
# 856  410   52    1        1          1        0      479        1     0
#
#      contact  day  month  campaign  response
# 0          0   18      8         0         3
# ...

# %%
data['prediction']=optimized_model.predict_proba(data.iloc[:,1:])[:,1]

# %%
data
# Out:
#       ID  age  job  marital  education  default  balance  housing  loan  \
# 0    812   25    1        2          1        0      325        2     0
# 1     71   40    1        2          3        0      111        1     0
# 2    912   27    0        0          1        0      246        2     0
# 3     43   30    7        2          1        0      262        2     0
# 4    431   36    1        1          3        0      452        2     1
# ..   ...  ...  ...      ...        ...      ...      ...      ...   ...
# 852   49   43    1        1          1        0      236        2     0
# 853  409   56    4        1          2        0      420        1     0
# 854  105   54    0        1          3        0      378        2     0
# 855  810   30   10        2          2        0      398        1     0
# 856  410   52    1        1          1        0      479        1     0
#
#      contact  day  month  campaign  response  prediction
# ...
